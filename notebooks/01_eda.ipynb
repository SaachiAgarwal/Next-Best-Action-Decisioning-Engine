# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# Initial exploration of the H&M dataset for the Next-Best-Action engine.
#
# > Placeholder notebook. Load the H&M CSVs into `data/raw/` before running.

# %%
from src import config

config.RAW_DIR
